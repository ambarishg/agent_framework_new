# %%
from client import *
from common_imports import *
from agent_framework import MCPStreamableHTTPTool

# %%
async with (
        MCPStreamableHTTPTool(
            name="Microsoft Learn MCP",
            url="https://learn.microsoft.com/api/mcp",
        ) as mcp_server,
        Agent(
            client=client,
            instructions=(
                "You help with Microsoft documentation questions. "
                "Use the available tools to search for relevant docs."
            ),
            tools=[mcp_server],
        ) as agent,
    ):
        response = await agent.run("How do I create an Azure storage account using az cli?")
        print(response.text)
# Out:
# To create an Azure Storage Account using the Azure CLI, you can follow these steps:
#
# ### **Step-by-Step**
#
# 1. **Create a Resource Group**:
#    First, create a new resource group in which your storage account will reside.
#
#    ```bash
#    az group create --name myResourceGroup --location eastus
#    ```
#
#    Replace `myResourceGroup` with your preferred resource group name and specify a location supported by Azure, such as `eastus`.
#
# 2. **Create a Storage Account**:
#    Use the `az storage account create` command to create the storage account. Replace `<account-name>` with a globally unique name for the storage account.
#
#    ```bash
#    az storage account create \
#      --name <account-name> \
#      --resource-group myResourceGroup \
#      --location eastus \
#      --sku Standard_RAGRS \
#      --kind StorageV2 \
#      --min-tls-version TLS1_2 \
#      --allow-blob-public-access false
#    ```
#
#    - `--sku Standard_RAGRS` specifies the replication type (Read-Access Geo-Redundant Storage in this case).
#    - `--kind StorageV2` defines the account type as a general-purpose v2 storage account.
#    - `--min-tls-version TLS1_2` ensures secure connections.
#    - `--allow-blob-public-access false` prevents public access to blob data.
#
# 3. **Confirm the Creation**:
#    After execution, Azure will output details about the created storage account. To verify, you can list the storage accounts in your resource group:
#
#    ```bash
#    az storage account list --resource-group myResourceGroup --query "[].{Name:name, Location:location}" --output table
#    ```
#
# 4. **Optional - Enable Hierarchical Namespace** (For Data Lake Storage):
#    If you want to enable a hierarchical namespace for Data Lake Storage (Azure Data Lake), add the `--enable-hierarchical-namespace true` flag to the `az storage account create` command.
#
#    ```bash
#    az storage account create \
#      --name <account-name> \
#      --resource-group myResourceGroup \
#      --location eastus \
#      --sku Standard_RAGRS \
#      --kind StorageV2 \
#      --enable-hierarchical-namespace true
#    ```
#
# ### **Additional Resources**
# For more options, see the full [Azure CLI documentation for `az storage account create`](https://learn.microsoft.com/azure/storage/common/storage-account-create#create-a-storage-account).
