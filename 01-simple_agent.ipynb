# %%
from client import *

# %%
agent = Agent(client=client, 
instructions="You are good at telling jokes.",
    name="Joker")

# %%
response = await agent.run("Tell me a joke about a pirate.")

# %%
print(response)
# Out:
# Sure thing! Here's a pirate joke for you:
#
# Why couldn't the pirate finish his alphabet?
#
# Because he got stuck at **"R"**—and had to sail the seven Cs! 🏴‍☠️
