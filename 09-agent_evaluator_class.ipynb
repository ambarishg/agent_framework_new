# %%
from typing import Annotated

from pydantic import Field
from agent_framework import Agent, tool
from agent_evaluator import AgentEvaluator
from client import client, eval_model_config

AGENT_INSTRUCTIONS = "You are a travel planning assistant."

query = (
    "Plan a 3-day trip from New York to Tokyo. "
    "My budget is $2000 total. I like hiking and museums."
)

@tool
def get_weather(
    city: Annotated[str, Field(description="City name")],
) -> dict:
    return {"city": city, "forecast": "Sunny"}

tools = [get_weather]

agent = Agent(
    client=client,
    instructions=AGENT_INSTRUCTIONS,
    tools=tools,
)

response = await agent.run(query)
ground_truth = (
    "A complete itinerary with flights, hotels, activities, weather, "
    "and a cost breakdown that stays within budget."
)

evaluator = AgentEvaluator(
    model_config=eval_model_config,
    is_reasoning_model=False,
)

results = evaluator.evaluate_run(
    query=query,
    agent_run=response,
    system_message=AGENT_INSTRUCTIONS,
    tool_definitions=tools,
    ground_truth=ground_truth,
)

evaluator.display_results(results)
# Out:
# Class IntentResolutionEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ResponseCompletenessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class TaskAdherenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ToolCallAccuracyEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                              Agent Evaluation Results
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Evaluator                ┃ Score ┃ Result ┃ Reason                                                              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ IntentResolution         │  5.0  │  pass  │ User wanted a 3-day Tokyo trip plan within a $2,000 budget,         │
# │                          │       │        │ focusing on hiking and museums. Agent provided a detailed           │
# │                          │       │        │ itinerary, budget breakdown, and relevant recommendations, fully    │
# │                          │       │        │ resolving the intent with thoroughness and accuracy.                │
# ├──────────────────────────┼───────┼────────┼─────────────────────────────────────────────────────────────────────┤
# │ ResponseCompleteness     │  4.0  │  pass  │ Let's think step by step: The Response provides a detailed 3-day    │
# │                          │       │        │ itinerary for a Tokyo trip, including flights, accommodations,      │
# │                          │       │        │ activities, transportation, and a cost breakdown. It aligns well    │
# │                          │       │        │ with the Ground Truth's requirement for a complete itinerary that   │
# │                          │       │        │ includes flights, hotels, activities, and a cost breakdown within   │
# │                          │       │        │ budget. However, the Ground Truth also specifies the inclusion of   │
# │                          │       │        │ weather information, which is missing in the Response. While the    │
# │                          │       │        │ Response is thorough in most aspects, the omission of weather       │
# │                          │       │        │ details means it is not fully complete. Therefore, the Response is  │
# │                          │       │        │ mostly complete but not fully complete.                             │
# ├──────────────────────────┼───────┼────────┼─────────────────────────────────────────────────────────────────────┤
# │ TaskAdherence            │  1.0  │  pass  │ The assistant successfully provided a detailed 3-day travel plan    │
# │                          │       │        │ from New York to Tokyo within a $2,000 budget. It adhered to the    │
# │                          │       │        │ user's preferences for hiking and museums, including relevant       │
# │                          │       │        │ activities such as a hike at Mount Takao and visits to the Tokyo    │
# │                          │       │        │ National Museum and Ghibli Museum. The plan accounted for flights,  │
# │                          │       │        │ accommodations, food, transportation, and attractions with          │
# │                          │       │        │ estimated costs, demonstrating alignment with the user's budgetary  │
# │                          │       │        │ constraint. There are no indications of safety, privacy, or         │
# │                          │       │        │ procedural violations, and no external verification was required    │
# │                          │       │        │ for the task.                                                       │
# ├──────────────────────────┼───────┼────────┼─────────────────────────────────────────────────────────────────────┤
# │ ToolCallAccuracy         │ None  │ not_a… │ Not applicable: No tool calls found in response or provided         │
# │                          │       │        │ tool_calls.                                                         │
# └──────────────────────────┴───────┴────────┴─────────────────────────────────────────────────────────────────────┘
