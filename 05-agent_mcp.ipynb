# %%
from client import *
from common_imports import *

# %%
MCP_SERVER_URL = os.getenv("MCP_SERVER_URL", "http://localhost:8000/mcp")

# %%
async with (
        MCPStreamableHTTPTool(name="Expenses MCP Server", url=MCP_SERVER_URL) as mcp_server,
        Agent(
            client=client,
            instructions=(
                "You help users with tasks using the available tools. "
                f"Today's date is {datetime.now().strftime('%Y-%m-%d')}."
            ),
            tools=[mcp_server],
        ) as agent,
    ):
        response = await agent.run("yesterday I bought a laptop for $1200 using my visa, log this expense")
        print(response.text)
# Out:
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\anyio\streams\memory.py:117, in MemoryObjectReceiveStream.receive(self)
#     116 try:
# --> 117     return self.receive_nowait()
#     118 except WouldBlock:
#     119     # Add ourselves in the queue
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\anyio\streams\memory.py:112, in MemoryObjectReceiveStream.receive_nowait(self)
#     110     raise EndOfStream
# --> 112 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 async with (
#       2         MCPStreamableHTTPTool(name="Expenses MCP Server", url=MCP_SERVER_URL) as mcp_server,
#       3         Agent(
#       4             client=client,
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_mcp.py:1215, in MCPTool.__aenter__(self)
#    1203 """Enter the async context manager.
#    1204
#    1205 Connects to the MCP server automatically.
#    (...)   1212     ToolExecutionException: If context manager setup fails.
#    1213 """
#    1214 try:
# -> 1215     await self.connect()
#    1216     return self
#    1217 except ToolException:
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_mcp.py:636, in MCPTool.connect(self, reset)
#     633     return
#     635 async with self._lifecycle_request_lock:
# --> 636     await self._run_on_lifecycle_owner("connect", reset=reset)
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_mcp.py:611, in MCPTool._run_on_lifecycle_owner(self, action, reset)
#     609 future = asyncio.get_running_loop().create_future()
#     610 await queue.put((action, reset, future))
# --> 611 await future
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_mcp.py:555, in MCPTool._run_lifecycle_owner(self)
#     553 try:
#     554     if action == "connect":
# --> 555         await self._connect_on_owner(reset=reset)
#     556     elif action == "close":
#     557         await self._close_on_owner()
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_mcp.py:702, in MCPTool._connect_on_owner(self, reset)
#     697     raise ToolException(
#     698         message="Failed to create MCP session. Please check your configuration.",
#     699         inner_exception=ex,
#     700     ) from ex
#     701 try:
# --> 702     await session.initialize()
#     703 except Exception as ex:
#     704     await self._safe_close_exit_stack()
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\mcp\client\session.py:183, in ClientSession.initialize(self)
#     166 elicitation = (
#     167     types.ElicitationCapability(
#     168         form=types.FormElicitationCapability(),
#    (...)    172     else None
#     173 )
#     174 roots = (
#     175     # TODO: Should this be based on whether we
#     176     # _will_ send notifications, or only whether
#    (...)    180     else None
#     181 )
# --> 183 result = await self.send_request(
#     184     types.ClientRequest(
#     185         types.InitializeRequest(
#     186             params=types.InitializeRequestParams(
#     187                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     188                 capabilities=types.ClientCapabilities(
#     189                     sampling=sampling,
#     190                     elicitation=elicitation,
#     191                     experimental=None,
#     192                     roots=roots,
#     193                     tasks=self._task_handlers.build_capability(),
#     194                 ),
#     195                 clientInfo=self._client_info,
#     196             ),
#     197         )
#     198     ),
#     199     types.InitializeResult,
#     200 )
#     202 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     203     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\mcp\shared\session.py:292, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     290 try:
#     291     with anyio.fail_after(timeout):
# --> 292         response_or_error = await response_stream_reader.receive()
#     293 except TimeoutError:
#     294     raise McpError(
#     295         ErrorData(
#     296             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    302         )
#     303     )
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\anyio\streams\memory.py:125, in MemoryObjectReceiveStream.receive(self)
#     122 self._state.waiting_receivers[receive_event] = receiver
#     124 try:
# --> 125     await receive_event.wait()
#     126 finally:
#     127     self._state.waiting_receivers.pop(receive_event, None)
#
# File c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1840, in Event.wait(self)
#    1838     await AsyncIOBackend.checkpoint()
#    1839 else:
# -> 1840     await self._event.wait()
#
# File C:\Applications\Python\Lib\asyncio\locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError: Cancelled via cancel scope 17b50166990
