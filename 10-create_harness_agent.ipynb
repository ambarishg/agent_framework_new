# %%
from agent_framework import create_harness_agent
# Out:
# c:\Ambarish\agent_framework_new\.venv\Lib\site-packages\agent_framework\_harness\_file_access.py:621: ExperimentalWarning: [HARNESS] AgentFileStore is experimental and may change or be removed in future versions without notice.

# %%
from client import *
from common_imports import *

# %%
agent = create_harness_agent(
    client=client,
)

session = agent.create_session()
response = await agent.run("Plan a weekend trip to Seattle.", session=session)
print(response.text)
# Out:
# HistoryProvider 'in_memory' has load_messages=True but the chat client stores history server-side; skipping local history load and relying on the service-managed conversation. Set store=False to load from the provider, or load_messages=False to silence this warning.
# Let’s start planning your weekend trip to Seattle! A thorough plan would involve considering transportation,
# accommodations, activities, meals, and any specific preferences you might have.
#
# ### Questions for Clarification:
# 1. **Dates**: Which weekend are you planning to go? (For example: exact dates)
# 2. **Budget**: Do you have a preferred budget for accommodations, activities, and dining?
# 3. **Transportation**:
#    - Are you driving, flying, or taking another mode of transportation to Seattle?
# 4. **Accommodation Preferences**:
#    - Do you have a preferred type of lodging (hotel, Airbnb, etc.)?
#    - Any specific areas in Seattle where you'd like to stay?
# 5. **Activities**:
#    - Are there any landmarks, museums, or activities you specifically want to include (e.g., Space Needle, Pike
# Place Market, museums, nature exploration)?
# 6. **Dining**:
#    - Do you have any dietary restrictions, cuisine preferences, or specific restaurants in mind?
# 7. **Travel Companions**:
#    - Will you be traveling solo, with a partner, family, or friends? This could impact plans for group-friendly
# activities.
# 8. **Pace**:
#    - Do you prefer a packed itinerary or a more relaxed trip with fewer planned activities?
#
# Once I have these details, I can create a more personalized and detailed plan for your Seattle weekend. Let me know
# how you'd like to proceed!
